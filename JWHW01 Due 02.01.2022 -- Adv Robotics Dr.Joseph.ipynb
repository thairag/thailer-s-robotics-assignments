# %% [markdown]
# # Problem 1 #

# %% [raw]
# This purpose of this chapter is to familiarize students with the role of algebra and the history of numbers and how these are two subject matters relating to the systems of linear equations. The history of numbers identify many different types of categories of numbers. The earliest philosophers, scientists, and mathemeticians decided to categorize numbers for the sake of broadening their understanding of not only how numbers work but of how applicable these concepts are to the world around us. These categories include natural or counting numbers, rational and irration numbers, and even complex or imaginary numbers. These are just a few categories to name a few. Also there are many different ways of finding solutions to systems of linear equations. Some equations have one unique solution, no solution, or infinitely many solutions. One thing I found most interesting about this chapter is that Pythagoras' idea of the sqaure root of 2 not being accepted for a long time as an irrational number because at the time of his discovery of his theorem, there was no such thing as irrational numbers. Also finding solutions to equations by hand isn't always the best when it comes to dealing with problems of infinitely many solutions or no solution.

# %%
import Pkg
Pkg.add("Plots")
using Plots

gr()
# Out:
#     Updating registry at `C:\Users\tailo\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed libvorbis_jll ─ v1.3.7+1
#   No Changes to `C:\Users\tailo\.julia\environments\v1.7\Project.toml`
#     Updating `C:\Users\tailo\.julia\environments\v1.7\Manifest.toml`
#   [f27f6e37] ↑ libvorbis_jll v1.3.7+0 ⇒ v1.3.7+1
# Precompiling project...
#   ✓ libvorbis_jll
#   ✓ FFMPEG_jll
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ GR
#   ✓ Plots
#   6 dependencies successfully precompiled in 45 seconds (128 already precompiled)
# Plots.GRBackend()

# %% [markdown]
# # Problem 2 #

# %%
a(x) = .5x + 1
b(x) = -x + 4
plot([a,b])

# %% [markdown]
# POINT OF INTERSECTION AT (2,2)

# %% [markdown]
# # Problem 3 #

# %%
a(x) = 2x + 1
b(x) = 2x + 4
plot([a,b])

# %% [markdown]
# THESE TWO LINES SHARE THE SAME SLOPE OF +2, THEREFORE THESE TWO LINES WILL NOT INTERESECT

# %% [markdown]
# # Problem 4 #

# %%
a(x) = -4 + x + 2x^2
b(x) = 0
c(x) = 2
plot([a,b,c], -3, 3)

# %% [markdown]
# WHEN Y=0, X HAS VALUES OF APPROXMATELY X=-1.75 AND X=1.25
#
# WHEN Y=2, X HAS VLAUES OF APPROXIMATELY X=-2 AND X=1.5

# %% [markdown]
# # Problem 5 #

# %% [markdown]
# Discriminate of 2x^2 + 3x - 2 = 0

# %% [markdown]
# Discriminate = b^2 - 4ac
#
# a = 2
#
# b = 3
#
# c = -2
#
# Therefore the discriminate = 25

# %% [markdown]
# # Problem 6 #

# %% [markdown]
# Discriminate of 2x^2 + 3x + 2 = 0
#
# Discriminate = b^2 - 4ac
#
# a = 2
#
# b = 3
#
# c = 2
#
# Therefore the discriminate = -7
